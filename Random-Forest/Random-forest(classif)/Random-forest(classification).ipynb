# %% [markdown]
# **Random Forest Algorithm for Classification problem**

# %% [markdown]
# #Wine Quality Prediction

# %%
#Loading the dataset
import pandas as pd
wine_data=pd.read_csv("winequality-red.csv")
wine_data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine_data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
#Data cleaning
wine_data.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# **Data-Analysis and Visualization**

# %%
#sataistical measures of the dataset
wine_data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
#number of values for each quality
import seaborn as sns
sns.catplot(x='quality',data=wine_data,kind='count')

# %%
#Volatile acidity vs Quality
import matplotlib.pyplot as plt
import seaborn as sns
plot = plt.figure(figsize=(5,5))
sns.barplot(x='quality',y='volatile acidity',data=wine_data)
# Out:
# <Axes: xlabel='quality', ylabel='volatile acidity'>

# %%
# Get all feature columns except 'quality'
features = [col for col in wine_data.columns if col != 'quality']

# Decide rows and columns based on number of features
n = len(features)    # Total number of features (excluding 'quality')
rows = (n // 3) + 1  # Adjust based on layout(Har row me 3 plots honge)
cols = 3

# Create subplots
fig, axes = plt.subplots(rows, cols, figsize=(18, 15))
axes = axes.flatten()  # Convert 2D array to 1D for easy access

# Plot each feature vs quality
for i, feature in enumerate(features):
    sns.barplot(x='quality', y=feature, data=wine_data, ax=axes[i])
    axes[i].set_title(f'{feature} vs Quality')

# Hide any unused subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# **Data Preprocessing**

# %%
#splitting dataset into input(x) and output(y)
x=wine_data.drop('quality',axis=1)
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
y=wine_data['quality'].apply(lambda y_value:1 if y_value>=7 else 0) #only represent the quality by 0 or 1 
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1594    0
# 1595    0
# 1596    0
# 1597    0
# 1598    0
# Name: quality, Length: 1599, dtype: int64

# %%
#Train & Test split

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=3)
print(y.shape , y_train.shape , y_test.shape)
# Out:
# (1599,) (1279,) (320,)

# %%
#Model Training (using RandomFotrest Classifier)

from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()

model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
#Model Evaluation

#Accuracy on test data
from sklearn.metrics import accuracy_score
x_test_pred=model.predict(x_test)
test_data_accuracy=accuracy_score(x_test_pred,y_test)

print('Accuracy on test data:',test_data_accuracy)
# Out:
# Accuracy: 0.928125

# %%
#Accuracy on train data
from sklearn.metrics import accuracy_score
x_train_pred=model.predict(x_train)
train_data_accuracy=accuracy_score(x_train_pred,y_train)

print('Accuracy on train data:',train_data_accuracy)
# Out:
# Accuracy: 1.0

# %% [markdown]
# **Building a Predictive system**

# %%
input_data=(7.8,0.760,0.04,2.3,0.092,15.0,54.0,0.99700,3.26,0.65,9.8)  # from training data
# Step 1: changing the input data to numpy array
import numpy as np
input_data_as_numpy_array = np.asarray(input_data)
# Step 2: Reshape since we’re predicting for one sample beacuse model.predict() expects 2D array:(n_samples, n_features)
input_data_reshaped = input_data_as_numpy_array.reshape(1, -1)
# Step 3: Predict
prediction = model.predict(input_data_reshaped)
# Step 4: Output
print(prediction)

if (prediction[0])
# Out:
# [0]
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
